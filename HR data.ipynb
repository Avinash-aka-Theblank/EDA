# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
# ...

# %%
df = pd.read_csv('HR_data.csv')

# %%
df.head()
# Out:
#    SLNO  Candidate Ref DOJ Extended  Duration to accept offer  Notice period  \
# 0     1        2110407          Yes                        14             30
# 1     2        2112635           No                        18             30
# 2     3        2112838           No                         3             45
# 3     4        2115021           No                        26             30
# 4     5        2115125          Yes                         1            120
#
#   Offered band  Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0           E2                       -20.79                        13.16
# 1           E2                        50.00                       320.00
# 2           E2                        42.84                        42.84
# 3           E2                        42.84                        42.84
# 4           E2                        42.59                        42.59
#
# ...

# %%
df.drop('SLNO',axis = 1, inplace =True)

# %%
df
# Out:
#       Candidate Ref DOJ Extended  Duration to accept offer  Notice period  \
# 0           2110407          Yes                        14             30
# 1           2112635           No                        18             30
# 2           2112838           No                         3             45
# 3           2115021           No                        26             30
# 4           2115125          Yes                         1            120
# ...             ...          ...                       ...            ...
# 8990        3822427           No                         4              0
# 8991        3828206          Yes                         2              0
# 8992        3834159           No                         0              0
# 8993        3835433           No                         0             30
# 8994        3836076           No                         2              0
#
#      Offered band  Pecent hike expected in CTC  Percent hike offered in CTC  \
# ...

# %%
df.drop('Candidate Ref',axis = 1, inplace =True)

# %%
df
# Out:
#      DOJ Extended  Duration to accept offer  Notice period Offered band  \
# 0             Yes                        14             30           E2
# 1              No                        18             30           E2
# 2              No                         3             45           E2
# 3              No                        26             30           E2
# 4             Yes                         1            120           E2
# ...           ...                       ...            ...          ...
# 8990           No                         4              0           E1
# 8991          Yes                         2              0           E1
# 8992           No                         0              0           E2
# 8993           No                         0             30           E1
# 8994           No                         2              0           E1
#
#       Pecent hike expected in CTC  Percent hike offered in CTC  \
# ...

# %%
sns.countplot(df['Status'],hue = df['Gender'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %%
df.shape
# Out:
# (8995, 16)

# %%
df['Gender'].value_counts()
# Out:
# Male      7444
# Female    1551
# Name: Gender, dtype: int64

# %%
df['Gender'].count()
# Out:
# 8995

# %%
male_female = pd.DataFrame((df['Gender'].value_counts()/df['Gender'].count())*100)

# %%
male_female
# Out:
#            Gender
# Male    82.757087
# Female  17.242913

# %%
df.groupby('Gender')['Status'].value_counts()
# Out:
# Gender  Status
# Female  Joined        1278
#         Not Joined     273
# Male    Joined        6035
#         Not Joined    1409
# Name: Status, dtype: int64

# %%
df=df.rename(columns = {'Offered band':'band'})

# %%
df
# Out:
#      DOJ Extended  Duration to accept offer  Notice period band  \
# 0             Yes                        14             30   E2
# 1              No                        18             30   E2
# 2              No                         3             45   E2
# 3              No                        26             30   E2
# 4             Yes                         1            120   E2
# ...           ...                       ...            ...  ...
# 8990           No                         4              0   E1
# 8991          Yes                         2              0   E1
# 8992           No                         0              0   E2
# 8993           No                         0             30   E1
# 8994           No                         2              0   E1
#
#       Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0                          -20.79                        13.16
# 1                           50.00                       320.00
# ...

# %%
for i in range(len(df['band'])):
    if df['band'][i] == 'E1':
        df['band'][i] = 'More than 10L'
    elif df['band'][i] == 'E2':
        df['band'][i] = 'More than 7L'
    elif df['band'][i] == 'E3':
        df['band'][i] = 'More than 5L'
    else:
        df['band'][i] ='More than 3L'

# %%
df
# Out:
#      DOJ Extended  Duration to accept offer  Notice period           band  \
# 0             Yes                        14             30   More than 7L
# 1              No                        18             30   More than 7L
# 2              No                         3             45   More than 7L
# 3              No                        26             30   More than 7L
# 4             Yes                         1            120   More than 7L
# ...           ...                       ...            ...            ...
# 8990           No                         4              0  More than 10L
# 8991          Yes                         2              0  More than 10L
# 8992           No                         0              0   More than 7L
# 8993           No                         0             30  More than 10L
# 8994           No                         2              0  More than 10L
#
#       Pecent hike expected in CTC  Percent hike offered in CTC  \
# ...

# %%
df
# Out:
#      DOJ Extended  Duration to accept offer  Notice period           band  \
# 0             Yes                        14             30   More than 7L
# 1              No                        18             30   More than 7L
# 2              No                         3             45   More than 7L
# 3              No                        26             30   More than 7L
# 4             Yes                         1            120   More than 7L
# ...           ...                       ...            ...            ...
# 8990           No                         4              0  More than 10L
# 8991          Yes                         2              0  More than 10L
# 8992           No                         0              0   More than 7L
# 8993           No                         0             30  More than 10L
# 8994           No                         2              0  More than 10L
#
#       Pecent hike expected in CTC  Percent hike offered in CTC  \
# ...

# %%
df.groupby('band')['Status'].value_counts()
# Out:
# band           Status
# More than 10L  Joined        4527
#                Not Joined    1041
# More than 3L   Joined         161
#                Not Joined      50
# More than 5L   Joined         430
#                Not Joined      75
# More than 7L   Joined        2195
#                Not Joined     516
# Name: Status, dtype: int64

# %%
sns.countplot(df['band'],hue = df['Status'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
# <AxesSubplot:xlabel='band', ylabel='count'>

# %%
df['band'].unique()
# Out:
# array(['More than 7L', 'More than 10L', 'More than 5L', 'More than 3L'],
#       dtype=object)

# %%
df3 = pd.DataFrame((df.groupby(['band','Gender'])['Status'].value_counts()/df.groupby(['band','Gender'])['Status'].count())*100)

# %%
df.groupby('band')['Status'].count()
# Out:
# band
# More than 10L    5568
# More than 3L      211
# More than 5L      505
# More than 7L     2711
# Name: Status, dtype: int64

# %%
df3
# Out:
#                                     Status
# band          Gender Status
# More than 10L Female Joined      82.636364
#                      Not Joined  17.363636
#               Male   Joined      80.975828
#                      Not Joined  19.024172
# More than 3L  Female Joined      76.106195
#                      Not Joined  23.893805
#               Male   Joined      76.530612
#                      Not Joined  23.469388
# More than 5L  Female Joined      78.571429
#                      Not Joined  21.428571
#               Male   Joined      85.534591
#                      Not Joined  14.465409
# More than 7L  Female Joined      84.193548
#                      Not Joined  15.806452
#               Male   Joined      80.549771
#                      Not Joined  19.450229

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#   DOJ Extended  Duration to accept offer  Notice period          band  \
# 0          Yes                        14             30  More than 7L
# 1           No                        18             30  More than 7L
# 2           No                         3             45  More than 7L
# 3           No                        26             30  More than 7L
# 4          Yes                         1            120  More than 7L
#
#    Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0                       -20.79                        13.16
# 1                        50.00                       320.00
# 2                        42.84                        42.84
# 3                        42.84                        42.84
# 4                        42.59                        42.59
#
#    Percent difference CTC Joining Bonus Candidate relocate actual  Gender  \
# 0                   42.86            No                        No  Female
# ...

# %%
df=df.rename(columns = {'Rex in Yrs':'Experience'})

# %%
df.groupby(['DOJ Extended','Gender'])['Status'].value_counts()
# Out:
# DOJ Extended  Gender  Status
# No            Female  Joined         691
#                       Not Joined     149
#               Male    Joined        3191
#                       Not Joined     757
# Yes           Female  Joined         587
#                       Not Joined     124
#               Male    Joined        2844
#                       Not Joined     652
# Name: Status, dtype: int64

# %%
df['DOJ Extended'].value_counts()
# Out:
# No     4788
# Yes    4207
# Name: DOJ Extended, dtype: int64

# %%
df['Status'].value_counts()
# Out:
# Joined        7313
# Not Joined    1682
# Name: Status, dtype: int64

# %%
x = (df.groupby('DOJ Extended')['Status'].value_counts()/df['Status'].count())*100

# %%
x
# Out:
# DOJ Extended  Status
# No            Joined        43.157310
#               Not Joined    10.072262
# Yes           Joined        38.143413
#               Not Joined     8.627015
# Name: Status, dtype: float64

# %%
(df.groupby(['DOJ Extended','Gender'])['Status'].value_counts()/df.groupby(['DOJ Extended','Gender'])['Status'].count())*100
# Out:
# DOJ Extended  Gender  Status
# No            Female  Joined        82.261905
#                       Not Joined    17.738095
#               Male    Joined        80.825735
#                       Not Joined    19.174265
# Yes           Female  Joined        82.559775
#                       Not Joined    17.440225
#               Male    Joined        81.350114
#                       Not Joined    18.649886
# Name: Status, dtype: float64

# %%
df.groupby(['DOJ Extended','Gender'])['Status'].value_counts()
# Out:
# DOJ Extended  Gender  Status
# No            Female  Joined         691
#                       Not Joined     149
#               Male    Joined        3191
#                       Not Joined     757
# Yes           Female  Joined         587
#                       Not Joined     124
#               Male    Joined        2844
#                       Not Joined     652
# Name: Status, dtype: int64

# %%
df.groupby(['DOJ Extended','Gender'])['Status'].count()
# Out:
# DOJ Extended  Gender
# No            Female     840
#               Male      3948
# Yes           Female     711
#               Male      3496
# Name: Status, dtype: int64

# %%
df.head()
# Out:
#   DOJ Extended  Duration to accept offer  Notice period          band  \
# 0          Yes                        14             30  More than 7L
# 1           No                        18             30  More than 7L
# 2           No                         3             45  More than 7L
# 3           No                        26             30  More than 7L
# 4          Yes                         1            120  More than 7L
#
#    Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0                       -20.79                        13.16
# 1                        50.00                       320.00
# 2                        42.84                        42.84
# 3                        42.84                        42.84
# 4                        42.59                        42.59
#
#    Percent difference CTC Joining Bonus Candidate relocate actual  Gender  \
# 0                   42.86            No                        No  Female
# ...

# %%
sns.pairplot(df)

# %%
df.head()
# Out:
#   DOJ Extended  Duration to accept offer  Notice period          band  \
# 0          Yes                        14             30  More than 7L
# 1           No                        18             30  More than 7L
# 2           No                         3             45  More than 7L
# 3           No                        26             30  More than 7L
# 4          Yes                         1            120  More than 7L
#
#    Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0                       -20.79                        13.16
# 1                        50.00                       320.00
# 2                        42.84                        42.84
# 3                        42.84                        42.84
# 4                        42.59                        42.59
#
#    Percent difference CTC Joining Bonus Candidate relocate actual  Gender  \
# 0                   42.86            No                        No  Female
# ...

# %%
sns.kdeplot(df['Pecent hike expected in CTC'])
# Out:
# <AxesSubplot:xlabel='Pecent hike expected in CTC', ylabel='Density'>

# %%
y = df['Status']

# %%
y = y.map(lambda x:1 if x == 'Joined' else 0)

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 8990    1
# 8991    1
# 8992    1
# 8993    1
# 8994    1
# Name: Status, Length: 8995, dtype: int64

# %%
y.value_counts()
# Out:
# 1    7313
# 0    1682
# Name: Status, dtype: int64

# %%
df['Age'].unique()
# Out:
# array([34, 27, 32, 26, 29, 36, 30, 31, 40, 28, 33, 25, 44, 23, 41, 20, 37,
#        24, 35, 50, 42, 38, 39, 21, 45, 46, 43, 22, 49, 47, 48, 60, 51],
#       dtype=int64)

# %%
df['Age'] = pd.cut(df.Age,bins=[18,28,39,50,60,100],labels=['Teen','Young','Adult','Seniors','Elderly'])

# %%
df
# Out:
#      DOJ Extended  Duration to accept offer  Notice period           band  \
# 0             Yes                        14             30   More than 7L
# 1              No                        18             30   More than 7L
# 2              No                         3             45   More than 7L
# 3              No                        26             30   More than 7L
# 4             Yes                         1            120   More than 7L
# ...           ...                       ...            ...            ...
# 8990           No                         4              0  More than 10L
# 8991          Yes                         2              0  More than 10L
# 8992           No                         0              0   More than 7L
# 8993           No                         0             30  More than 10L
# 8994           No                         2              0  More than 10L
#
#       Pecent hike expected in CTC  Percent hike offered in CTC  \
# ...

# %%
df['Duration to accept offer'].unique()
# Out:
# array([ 14,  18,   3,  26,   1,  17,  37,  16,   6, 120,  44,   7,  98,
#          0,  83,  32,  19,   4,  38,  24,  10,  53,   5,  46,   2,  31,
#         54,  33, 105,  69,  68,  84,  28, 126, 106,  90,  21,  36,  34,
#         20,  13,   8,  42,  12, 103,  43,  60,  23,  67,  15,  45,  25,
#         47,  11,  48,  74,  30,  40,  35,  58,  29,  86,  51,  50,  39,
#         57,  93,  55,  71,  56,  66,  62,   9,  64, 107,  27,  78,  22,
#         49,  92,  61,  79,  77, 108,  70,  82, 210,  80,  97,  41,  59,
#         88,  99,  63, 111,  87,  95,  52,  96,  91, 101,  65, 140,  76,
#         73, 123, 104,  72, 117, 109,  89, 127,  81,  85,  75, 118, 114,
#        110, 129, 124, 116, 181,  94, 121, 119, 102, 113, 115, 125, 131,
#        100, 130, 224, 143, 122, 163], dtype=int64)

# %%
df.head()
# Out:
#   DOJ Extended  Duration to accept offer  Notice period          band  \
# 0          Yes                        14             30  More than 7L
# 1           No                        18             30  More than 7L
# 2           No                         3             45  More than 7L
# 3           No                        26             30  More than 7L
# 4          Yes                         1            120  More than 7L
#
#    Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0                       -20.79                        13.16
# 1                        50.00                       320.00
# 2                        42.84                        42.84
# 3                        42.84                        42.84
# 4                        42.59                        42.59
#
#    Percent difference CTC Joining Bonus Candidate relocate actual  Gender  \
# 0                   42.86            No                        No  Female
# ...

# %%
encoded_data[encoded_data['Percent difference CTC'] == 0.00]
# Out:
#       Duration to accept offer  Notice period  Pecent hike expected in CTC  \
# 2                            3             45                        42.84
# 3                           26             30                        42.84
# 4                            1            120                        42.59
# 5                           17             30                        42.83
# 6                           37             30                        31.58
# ...                        ...            ...                          ...
# 8986                         2              0                        25.00
# 8989                         0             30                        50.00
# 8990                         4              0                       191.67
# 8991                         2              0                       150.00
# 8992                         0              0                        35.42
#
# ...

# %%
encoded_data.drop('Percent difference CTC',axis = 1,inplace =True)

# %%
encoded_data
# Out:
#       Duration to accept offer  Notice period  Pecent hike expected in CTC  \
# 0                           14             30                       -20.79
# 1                           18             30                        50.00
# 2                            3             45                        42.84
# 3                           26             30                        42.84
# 4                            1            120                        42.59
# ...                        ...            ...                          ...
# 8990                         4              0                       191.67
# 8991                         2              0                       150.00
# 8992                         0              0                        35.42
# 8993                         0             30                        76.92
# 8994                         2              0                        45.25
#
#       Percent hike offered in CTC  Experience  DOJ Extended_Yes  \
# ...

# %%
df['Status'] = y

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 8990    1
# 8991    1
# 8992    1
# 8993    1
# 8994    1
# Name: Status, Length: 8995, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(encoded_data,y,test_size=0.30,random_state = 100)

# %%
import statsmodels.api as sm

# %%
model_1 = sm.Logit(y_train,x_train).fit()
# Out:
# ...
#          Current function value: 0.413884
#          Iterations: 35
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-432-7b8435dd23db> in <module>
# ----> 1 model_1 = sm.Logit(y_train,x_train).fit()
#
# ~\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1911         bnryfit = super(Logit, self).fit(start_params=start_params,
#    1912                 method=method, maxiter=maxiter, full_output=full_output,
# -> 1913                 disp=disp, callback=callback, **kwargs)
#    1914
#    1915         discretefit = LogitResults(self, bnryfit)
#
# ~\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#     214             start_params=start_params,
# ...

# %%
df
# Out:
#      DOJ Extended  Duration to accept offer  Notice period           band  \
# 0             Yes                        14             30   More than 7L
# 1              No                        18             30   More than 7L
# 2              No                         3             45   More than 7L
# 3              No                        26             30   More than 7L
# 4             Yes                         1            120   More than 7L
# ...           ...                       ...            ...            ...
# 8990           No                         4              0  More than 10L
# 8991          Yes                         2              0  More than 10L
# 8992           No                         0              0   More than 7L
# 8993           No                         0             30  More than 10L
# 8994           No                         2              0  More than 10L
#
#       Pecent hike expected in CTC  Percent hike offered in CTC  \
# ...

# %%
df.columns
# Out:
# Index(['DOJ Extended', 'Duration to accept offer', 'Notice period', 'band',
#        'Pecent hike expected in CTC', 'Percent hike offered in CTC',
#        'Percent difference CTC', 'Joining Bonus', 'Candidate relocate actual',
#        'Gender', 'Candidate Source', 'Experience', 'LOB', 'Location', 'Age',
#        'Status'],
#       dtype='object')

# %%
col = df[['DOJ Extended', 'Duration to accept offer', 'Notice period', 'band',
       'Percent difference CTC', 'Joining Bonus', 'Candidate relocate actual',
       'Gender', 'Candidate Source', 'Experience', 'LOB', 'Location', 'Age']]

# %%
col
# Out:
#      DOJ Extended  Duration to accept offer  Notice period           band  \
# 0             Yes                        14             30   More than 7L
# 1              No                        18             30   More than 7L
# 2              No                         3             45   More than 7L
# 3              No                        26             30   More than 7L
# 4             Yes                         1            120   More than 7L
# ...           ...                       ...            ...            ...
# 8990           No                         4              0  More than 10L
# 8991          Yes                         2              0  More than 10L
# 8992           No                         0              0   More than 7L
# 8993           No                         0             30  More than 10L
# 8994           No                         2              0  More than 10L
#
#       Percent difference CTC Joining Bonus Candidate relocate actual  Gender  \
# ...

# %%
eco = pd.get_dummies(col,drop_first=True)

# %%
eco
# Out:
#       Duration to accept offer  Percent difference CTC  Experience  \
# 0                           14                   42.86           7
# 1                           18                  180.00           8
# 2                            3                    0.00           4
# 3                           26                    0.00           4
# 4                            1                    0.00           6
# ...                        ...                     ...         ...
# 8990                         4                    0.00           1
# 8991                         2                    0.00           3
# 8992                         0                    0.00           5
# 8993                         0                  -13.04           4
# 8994                         2                  -21.45           1
#
#       DOJ Extended_Yes  band_More than 3L  band_More than 5L  \
# 0                    1                  0                  0
# ...

# %%
eco
# Out:
#       Duration to accept offer  Percent difference CTC  Experience  \
# 0                           14                   42.86           7
# 1                           18                  180.00           8
# 2                            3                    0.00           4
# 3                           26                    0.00           4
# 4                            1                    0.00           6
# ...                        ...                     ...         ...
# 8990                         4                    0.00           1
# 8991                         2                    0.00           3
# 8992                         0                    0.00           5
# 8993                         0                  -13.04           4
# 8994                         2                  -21.45           1
#
#       DOJ Extended_Yes  band_More than 3L  band_More than 5L  \
# 0                    1                  0                  0
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(eco,y,test_size=0.30,random_state = 100)

# %%
import statsmodels.api as sm

# %%
model_1 = sm.Logit(y_train,x_train).fit(method ='lbfgs')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\statsmodels\base\model.py:548: HessianInversionWarning:
#
# Inverting hessian failed, no bse or cov_params available
#
# C:\Users\user\anaconda3\lib\site-packages\statsmodels\base\model.py:568: ConvergenceWarning:
#
# Maximum Likelihood optimization failed to converge. Check mle_retvals

# %%
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                 Status   No. Observations:                 6296
# Model:                          Logit   Df Residuals:                     6263
# Method:                           MLE   Df Model:                           32
# Date:                Tue, 16 Mar 2021   Pseudo R-squ.:                 0.08675
# Time:                        16:14:44   Log-Likelihood:                -2776.7
# converged:                      False   LL-Null:                       -3040.5
# Covariance Type:            nonrobust   LLR p-value:                 4.722e-91
# ...
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Duration to accept offer              -0.0023        nan        nan        nan         nan         nan
# ...

# %%
exog = x_train.exog
u, s, vt = np.linalg.svd(exog, 0)
print(s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a06e0ff93dee> in <module>
# ----> 1 exog = x_train.exog
#       2 u, s, vt = np.linalg.svd(exog, 0)
#       3 print(s)
#
# NameError: name 'x_train' is not defined

# %%
df.head()
# Out:
#   DOJ Extended  Duration to accept offer  Notice period          band  \
# 0          Yes                        14             30  More than 7L
# 1           No                        18             30  More than 7L
# 2           No                         3             45  More than 7L
# 3           No                        26             30  More than 7L
# 4          Yes                         1            120  More than 7L
#
#    Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0                       -20.79                        13.16
# 1                        50.00                       320.00
# 2                        42.84                        42.84
# 3                        42.84                        42.84
# 4                        42.59                        42.59
#
#    Percent difference CTC Joining Bonus Candidate relocate actual  Gender  \
# 0                   42.86            No                        No  Female
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot = True)
# Out:
# <AxesSubplot:>

# %%
df.head(3)
# Out:
#   DOJ Extended  Duration to accept offer  Notice period          band  \
# 0          Yes                        14             30  More than 7L
# 1           No                        18             30  More than 7L
# 2           No                         3             45  More than 7L
#
#    Pecent hike expected in CTC  Percent hike offered in CTC  \
# 0                       -20.79                        13.16
# 1                        50.00                       320.00
# 2                        42.84                        42.84
#
#    Percent difference CTC Joining Bonus Candidate relocate actual  Gender  \
# 0                   42.86            No                        No  Female
# 1                  180.00            No                        No    Male
# 2                    0.00            No                        No    Male
#
#     Candidate Source  Rex in Yrs    LOB Location    Age  Status
# 0             Agency           7    ERS    Noida  Young  Joined
# ...

# %%
df.drop(['Percent hike offered in CTC','Pecent hike expected in CTC','Notice period'],axis = 1,inplace = True)

# %%
df
# Out:
#      DOJ Extended  Duration to accept offer           band  \
# 0             Yes                        14   More than 7L
# 1              No                        18   More than 7L
# 2              No                         3   More than 7L
# 3              No                        26   More than 7L
# 4             Yes                         1   More than 7L
# ...           ...                       ...            ...
# 8990           No                         4  More than 10L
# 8991          Yes                         2  More than 10L
# 8992           No                         0   More than 7L
# 8993           No                         0  More than 10L
# 8994           No                         2  More than 10L
#
#       Percent difference CTC Joining Bonus Candidate relocate actual  Gender  \
# 0                      42.86            No                        No  Female
# 1                     180.00            No                        No    Male
# ...

# %%
y = df["Status"]

# %%
df1 = df.copy()

# %%
df1.drop('Status',axis = 1,inplace =True)

# %%
df1
# Out:
#      DOJ Extended  Duration to accept offer           band  \
# 0             Yes                        14   More than 7L
# 1              No                        18   More than 7L
# 2              No                         3   More than 7L
# 3              No                        26   More than 7L
# 4             Yes                         1   More than 7L
# ...           ...                       ...            ...
# 8990           No                         4  More than 10L
# 8991          Yes                         2  More than 10L
# 8992           No                         0   More than 7L
# 8993           No                         0  More than 10L
# 8994           No                         2  More than 10L
#
#       Percent difference CTC Joining Bonus Candidate relocate actual  Gender  \
# 0                      42.86            No                        No  Female
# 1                     180.00            No                        No    Male
# ...

# %%
encoded_data = pd.get_dummies(df1,drop_first=True)

# %%
encoded_data.drop('Percent difference CTC',axis = 1,inplace =True)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(encoded_data,y,test_size=0.30,random_state = 100)

# %%
import statsmodels.api as sm

# %%
model_1 = sm.Logit(y_train,x_train).fit()
# Out:
# ...
#          Current function value: inf
#          Iterations: 35
# C:\Users\user\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1747: RuntimeWarning:
#
# overflow encountered in exp
#
# C:\Users\user\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py:1800: RuntimeWarning:
#
# divide by zero encountered in log
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-63-7b8435dd23db> in <module>
# ----> 1 model_1 = sm.Logit(y_train,x_train).fit()
#
# ~\anaconda3\lib\site-packages\statsmodels\discrete\discrete_model.py in fit(self, start_params, method, maxiter, full_output, disp, callback, **kwargs)
#    1911         bnryfit = super(Logit, self).fit(start_params=start_params,
#    1912                 method=method, maxiter=maxiter, full_output=full_output,
# -> 1913                 disp=disp, callback=callback, **kwargs)
#    1914
# ...

# %%
y = y.map(lambda x:1 if x == 'Joined' else 0)

# %%
y.value_counts()
# Out:
# 1    7313
# 0    1682
# Name: Status, dtype: int64

# %%
x_train.describe()
# Out:
#        Duration to accept offer   Experience  DOJ Extended_Yes  \
# count               6296.000000  6296.000000       6296.000000
# mean                  21.345457     4.244600          0.466328
# std                   25.754402     2.542953          0.498905
# min                    0.000000     0.000000          0.000000
# 25%                    3.000000     3.000000          0.000000
# 50%                   10.000000     4.000000          0.000000
# 75%                   33.000000     6.000000          1.000000
# max                  224.000000    24.000000          1.000000
#
#        band_More than 3L  band_More than 5L  band_More than 7L  \
# count        6296.000000        6296.000000        6296.000000
# mean            0.024301           0.053844           0.300508
# std             0.153995           0.225727           0.458515
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# ...

# %%
encoded_data.describe()
# Out:
#        Duration to accept offer   Experience  DOJ Extended_Yes  \
# count               8995.000000  8995.000000       8995.000000
# mean                  21.434464     4.239022          0.467704
# std                   25.811616     2.547571          0.498984
# min                    0.000000     0.000000          0.000000
# 25%                    3.000000     3.000000          0.000000
# 50%                   10.000000     4.000000          0.000000
# 75%                   33.000000     6.000000          1.000000
# max                  224.000000    24.000000          1.000000
#
#        band_More than 3L  band_More than 5L  band_More than 7L  \
# count        8995.000000        8995.000000        8995.000000
# mean            0.023457           0.056142           0.301390
# std             0.151360           0.230209           0.458887
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# ...

# %%
pd.set_option('display.max_columns', None)

# %%
encoded_data.drop('Age_Elderly',axis = 1,inplace =True)

# %%
x_train.columns
# Out:
# Index(['Duration to accept offer', 'Experience', 'DOJ Extended_Yes',
#        'band_More than 3L', 'band_More than 5L', 'band_More than 7L',
#        'Joining Bonus_Yes', 'Candidate relocate actual_Yes', 'Gender_Male',
#        'Candidate Source_Direct', 'Candidate Source_Employee Referral',
#        'LOB_BFSI', 'LOB_CSMP', 'LOB_EAS', 'LOB_ERS', 'LOB_ETS',
#        'LOB_Healthcare', 'LOB_INFRA', 'LOB_MMS', 'Location_Bangalore',
#        'Location_Chennai', 'Location_Cochin', 'Location_Gurgaon',
#        'Location_Hyderabad', 'Location_Kolkata', 'Location_Mumbai',
#        'Location_Noida', 'Location_Others', 'Location_Pune', 'Age_Young',
#        'Age_Adult', 'Age_Seniors'],
#       dtype='object')

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.30,random_state = 100)

# %%
x_train.drop(['LOB_BFSI', 'LOB_CSMP', 'LOB_EAS', 'LOB_ERS', 'LOB_ETS',
       'LOB_Healthcare', 'LOB_INFRA', 'LOB_MMS'],axis = 1,inplace =True)

# %%
x_train = x_train[['Duration to accept offer', 'Experience', 'DOJ Extended_Yes',
       'Joining Bonus_Yes','Gender_Male',
       'Candidate Source_Direct', 'Candidate Source_Employee Referral',
       'LOB_BFSI', 'LOB_CSMP', 'LOB_EAS', 'LOB_ERS', 'LOB_ETS',
       'LOB_Healthcare', 'LOB_INFRA','Location_Bangalore',
       'Location_Chennai', 'Location_Gurgaon',
       'Location_Hyderabad', 'Location_Kolkata', 'Location_Mumbai',
       'Location_Noida','Location_Pune', 'Age_Young',
       'Age_Adult']]

# %%
x_train.describe()
# Out:
#        Duration to accept offer   Experience  DOJ Extended_Yes  \
# count               6296.000000  6296.000000       6296.000000
# mean                  21.345457     4.244600          0.466328
# std                   25.754402     2.542953          0.498905
# min                    0.000000     0.000000          0.000000
# 25%                    3.000000     3.000000          0.000000
# 50%                   10.000000     4.000000          0.000000
# 75%                   33.000000     6.000000          1.000000
# max                  224.000000    24.000000          1.000000
#
#        Joining Bonus_Yes  Gender_Male  Candidate Source_Direct  \
# count        6296.000000  6296.000000              6296.000000
# mean            0.046061     0.827827                 0.536213
# std             0.209634     0.377561                 0.498726
# min             0.000000     0.000000                 0.000000
# 25%             0.000000     1.000000                 0.000000
# ...

# %%
model_1 = sm.Logit(y_train,x_train).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.464159
#          Iterations 6

# %%
model_1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                 Status   No. Observations:                 6296
# Model:                          Logit   Df Residuals:                     6272
# Method:                           MLE   Df Model:                           23
# Date:                Tue, 16 Mar 2021   Pseudo R-squ.:                 0.03886
# Time:                        17:19:27   Log-Likelihood:                -2922.3
# converged:                       True   LL-Null:                       -3040.5
# Covariance Type:            nonrobust   LLR p-value:                 2.562e-37
# ...
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Duration to accept offer              -0.0042      0.001     -3.233      0.001      -0.007      -0.002
# ...

# %%
def get_significant_vars(lm):
    var_p_vals = pd.DataFrame(lm.pvalues)
    var_p_vals['vars'] = var_p_vals.index
    var_p_vals.columns = ['pvals','vars']
    return list(var_p_vals[var_p_vals.pvals <=0.05]['vars'])

# %%
get_significant_vars(final_model)
# Out:
# ['Duration to accept offer',
#  'Experience',
#  'DOJ Extended_Yes',
#  'Candidate Source_Direct',
#  'Candidate Source_Employee Referral',
#  'LOB_ETS',
#  'LOB_INFRA',
#  'Age_Young',
#  'Age_Adult']

# %%
significant_vars = get_significant_vars(final_model)

# %%
final_model1 = sm.Logit(y_train,sm.add_constant(x_train[significant_vars])).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.466642
#          Iterations 6

# %%
final_model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                 Status   No. Observations:                 6296
# Model:                          Logit   Df Residuals:                     6286
# Method:                           MLE   Df Model:                            9
# Date:                Tue, 16 Mar 2021   Pseudo R-squ.:                 0.03372
# Time:                        17:20:39   Log-Likelihood:                -2938.0
# converged:                       True   LL-Null:                       -3040.5
# Covariance Type:            nonrobust   LLR p-value:                 2.883e-39
# ...
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.1505      0.087     13.263      0.000       0.980       1.320
# ...

# %%
pred_y
# Out:
#       Actual  Predicted Probablities
# 6441       1                0.850097
# 8014       0                0.789937
# 5067       1                0.822642
# 7212       1                0.850703
# 3744       1                0.682470
# ...      ...                     ...
# 5764       1                0.778643
# 5522       1                0.797265
# 5220       1                0.739700
# 5118       0                0.783005
# 5643       1                0.737044
#
# [2699 rows x 2 columns]

# %%
final_model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ...
# Dep. Variable:                 Status   No. Observations:                 6296
# Model:                          Logit   Df Residuals:                     6286
# Method:                           MLE   Df Model:                            9
# Date:                Tue, 16 Mar 2021   Pseudo R-squ.:                 0.03372
# Time:                        17:21:58   Log-Likelihood:                -2938.0
# converged:                       True   LL-Null:                       -3040.5
# Covariance Type:            nonrobust   LLR p-value:                 2.883e-39
# ...
#                                          coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# const                                  1.1505      0.087     13.263      0.000       0.980       1.320
# ...

# %%
pred_y['Predicted Class'] =  pred_y['Predicted Probablities'].map(lambda x:1 if x >= 0.5 else 0)

# %%
pred_y = final_model1.predict(x_test)

# %%
pred_y
# Out:
# 6441    0.827102
# 8014    0.806993
# 5067    0.840966
# 7212    0.862334
# 3744    0.698389
#           ...
# 5764    0.801561
# 5522    0.807067
# 5220    0.750166
# 5118    0.790121
# 5643    0.790287
# Length: 2699, dtype: float64

# %%
x_test = sm.add_constant(x_test[significant_vars])

# %%
x_test
# Out:
#       const  Duration to accept offer  Experience  DOJ Extended_Yes  \
# 6441    1.0                         3           3                 0
# 8014    1.0                        20           3                 1
# 5067    1.0                         5           4                 1
# 7212    1.0                        69           3                 1
# 3744    1.0                        47           9                 1
# ...     ...                       ...         ...               ...
# 5764    1.0                         7           2                 1
# 5522    1.0                        33           3                 0
# 5220    1.0                         2           9                 0
# 5118    1.0                         4           6                 0
# 5643    1.0                         5           3                 1
#
#       Candidate Source_Direct  Candidate Source_Employee Referral  LOB_ETS  \
# ...

# %%
def draw_cm(actual,predicted):
    cm = metrics.confusion_matrix(actual,predicted,[1,0]from sklearn.metrics import confusion_matrix,classification_report)
    sns.heatmap(cm,annot = True,fmt = '.2f',xticklabels=['Bad Credit','Good Credit'],yticklabels=['Bad Credit','Good Credit'])
    plt.ylabel('True Labels')
    plt.xlabel('Predicted Labels')
    plt.show()

# %%
draw_cm(pred_y['Actual'],pred_y['Predicted Class'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning:
#
# Pass labels=[1, 0] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error

# %%
from sklearn.metrics import confusion_matrix,classification_report

# %%
confusion_matrix(pred_y['Actual'],pred_y['Predicted Class'])
# Out:
# array([[   0,  500],
#        [   0, 2199]], dtype=int64)

# %%
print(classification_report(pred_y['Actual'],pred_y['Predicted Class']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       500
#            1       0.81      1.00      0.90      2199
#
#     accuracy                           0.81      2699
#    macro avg       0.41      0.50      0.45      2699
# weighted avg       0.66      0.81      0.73      2699
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning:
#
# ...

# %%
x = sm.add_constant(encoded_data)

# %%
pred_y = pd.DataFrame({'Actual':y_test,'Predicted Probablities':final_model1.predict(x_test)})

# %%
pred_y
# Out:
#       Actual  Predicted Probablities
# 6441       1                0.827102
# 8014       0                0.806993
# 5067       1                0.840966
# 7212       1                0.862334
# 3744       1                0.698389
# ...      ...                     ...
# 5764       1                0.801561
# 5522       1                0.807067
# 5220       1                0.750166
# 5118       0                0.790121
# 5643       1                0.790287
#
# [2699 rows x 2 columns]

# %%
pred_y['Predicted Class'] =  pred_y['Predicted Probablities'].map(lambda x:1 if x >= 0.5 else 0)

# %%
def draw_cm(actual,predicted):
    cm = metrics.confusion_matrix(actual,predicted,[1,0])
    sns.heatmap(cm,annot = True,fmt = '.2f',xticklabels=['Bad Credit','Good Credit'],yticklabels=['Bad Credit','Good Credit'])
    plt.ylabel('True Labels')
    plt.xlabel('Predicted Labels')
    plt.show()

# %%
draw_cm(pred_y['Actual'],pred_y['Predicted Class'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: FutureWarning:
#
# Pass labels=[1, 0] as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error

# %%
confusion_matrix(pred_y['Actual'],pred_y['Predicted Class'])
# Out:
# array([[   0,  500],
#        [   0, 2199]], dtype=int64)

# %%
print(classification_report(pred_y['Actual'],pred_y['Predicted Class']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       500
#            1       0.81      1.00      0.90      2199
#
#     accuracy                           0.81      2699
#    macro avg       0.41      0.50      0.45      2699
# weighted avg       0.66      0.81      0.73      2699
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# C:\Users\user\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning:
#
# ...
